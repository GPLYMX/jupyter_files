# %% [markdown]
# # 问题一：

# %% [markdown]
# ### 预备步骤：将原始数据1中的peanut_test_data、peanut_traning_data放置在Question1文件夹中
# ![q1.PNG](attachment:q1.PNG)

# %% [markdown]
# ### 一、如何查看test_data的测试结果：
# ####      用jupyter打开Question1文件中的main.ipynb文件、窗口移动到最后即可

# %% [markdown]
# ### 二、如何测试新样本：
# #### 在Question1文件中的main.ipynb文件最后的main()函数中添加新样本路径，路径示例在函数的默认参数中有

# %% [markdown]
# ### 三、如何重新训练模型：
# #### 1、打开preprocessing.ipynb文件，依次运行前半部分cell，直到运行完generate_img函数
# #### 2、此时Question1文件夹中会生成花生壳、花生仁图片
# #### 3、手动进行数据集划分(划分好的数据已放在peanute文件中)
# #### 4、运行preprocessing.ipynb文件中的后半部分cell，可以查看到模型训练过程

# %% [markdown]
# # 问题二：

# %% [markdown]
# ### 预备步骤：将原始数据2中的cube_20221028_104126、cube_20221028_104439两个文件放入Question2文件夹中
# ![q2.PNG](attachment:q2.PNG)

# %% [markdown]
# ### 一、如何查看效果：
# #### 打开main.ipynb，拖动窗口至最底部即可；依次运行所有cell，重新生成结果(速度较慢，算法复杂度待优化)

# %% [markdown]
# ### 二、评价指标是什么：
# #### 代码注释有说明

# %% [markdown]
# ### 三、如何测试新的样本：
# #### 可在main()函数中修改file_list列表来添加新路径，然后运行main()函数即可
